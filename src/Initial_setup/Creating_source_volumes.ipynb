# %%
file_name = dbutils.widgets.get("file_name")

# %%
catalog_name = "project"
schema_name = "source"
# source_path = f"abfss://source@databricksproject44.dfs.core.windows.net/{file_name}"
volume_source_name = f"src_{file_name}";

spark.sql(f'CREATE SCHEMA IF NOT EXISTS project.{schema_name}')
source_volume = f"""CREATE VOLUME IF NOT EXISTS {catalog_name}.{schema_name}.{volume_source_name}
  """;
spark.sql(source_volume)

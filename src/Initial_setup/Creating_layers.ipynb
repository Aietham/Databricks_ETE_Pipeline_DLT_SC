# %%
catalog = 'project'
create_catalog = f"CREATE CATALOG IF NOT EXISTS {catalog}"
spark.sql(create_catalog)

# %%
layer_name = dbutils.widgets.get('layer_name')

# %%
create_schema = f"CREATE SCHEMA IF NOT EXISTS {catalog}.{layer_name}"
spark.sql(create_schema)

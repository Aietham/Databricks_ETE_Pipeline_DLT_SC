# %%
df = spark.read.format('parquet').load('/Volumes/project/volumes/source_regions_volume')
df.display()

# %%
# %sql
CREATE VOLUME IF NOT EXISTS project.volumes.silver_regions_int_volume

# %%
df.write.format('delta').save('/Volumes/project/volumes/silver_regions_int_volume/data')

# %%
# %sql
CREATE TABLE IF NOT EXISTS project.silver.regions
AS 
SELECT * FROM DELTA.`/Volumes/project/volumes/silver_regions_int_volume/data`

# %%
catalog = 'labuser11612924_1758377596'
bronze_tbl = f"{catalog}.bronze.customers"
silver_tbl = f"{catalog}.silver.dim_customers"

# %%
df1 = spark.sql(f'select * from {silver_tbl}')

# %%
df1.count()

# %%
df1.display()

# %%
df2 = df1.where('customer_id in ("C01986", "C02001", "C01992")')
df2.display()

# %%
df.display()

# %%
updated = spark.createDataFrame([
    ("C01986","Jason","Walker","jason.walker+primary@schaefer.com","Port Cameronborough","SD"),  # email updated
    ("C01987","Justin","Stein","phillipkirk@hotmail.com","Dillonview","KS"),                     # unchanged
    ("C01988","Emma","Blackwell","meganjones@wong.net","Portershire Heights","OH"),              # city updated
    ("C01989","Victoria","Wright","edavis@webb-parks.com","South James","DE"),                   # unchanged
    ("C01990","David","Davis","matthew76@gmail.com","Gallaghertown","GA"),                       # unchanged 
    ("C02001","Ava","Lopez","avalopez@example.org","Riverview","FL"),
    ("C01992","Andrew","Turner","pcross@mail.com","New Anthonybury","MT")    
], ["customer_id","first_name","last_name","email","city","state"])

# %%
updated.repartition(1).write.mode("append").parquet("/Volumes/labuser11612924_1758377596/source/customers")

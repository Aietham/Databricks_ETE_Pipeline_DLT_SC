# %%
datasets = [
    {
        "filename" : "orders"
    },
    {
        "filename" : "customers"
    },
    {
        "filename" : "products" 
    }
]

# %%
layers = [
    {
        "layer" : "bronze"
    },
    {
        "layer" : "silver"
    },
    {
        "layer" : "gold"
    }
]

# %%
matrix = [{"filename": d["filename"], "layer": l["layer"]}
          for d in datasets for l in layers]

# %%
# matrix

# %%
import json
dbutils.jobs.taskValues.set("output_matrix", json.dumps(matrix))
dbutils.jobs.taskValues.set("output_layers", layers)
dbutils.jobs.taskValues.set("output_datasets", datasets)

# %%
json.dumps(matrix)

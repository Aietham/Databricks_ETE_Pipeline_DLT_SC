# %% [markdown]
# # DLT Pipeline

# %% [markdown]
# ### Streaming Table

# %%
import dlt
from pyspark.sql import functions as F

# @dlt.table(name="products_stage")
# @dlt.expect_all_or_drop(rules)
# def products_stage():
#   df =  (spark.read.table("project.silver.products_silver")
#             .withColumn("run_ts", F.current_timestamp().cast("timestamp")))
#   return df

# %%
# @dlt.view
# def products_view():
#     df = spark.readStream.table('Live.products_stage')
#     return df

# %%
# @dlt.table(name="products_view")
# def products_cdf():
#     df = spark.readStream.table("project.silver.product_for_scd2")
#     trans_df = products_trans(df)

# %%
def products_trans(df):
    df = spark.read.table('products_view')
    df = df.withColumn('dimProductsKey',F.monotonically_increasing_id())
    return df

# %%
dlt.create_streaming_table(name='project.gold.products_dim')

# %%
dlt.apply_changes(
    target = 'project.gold.products_dim',
    source = 'products_view',
    keys = ['product_id'],
    sequence_by = 'event_ts',
    stored_as_scd_type =2
)
